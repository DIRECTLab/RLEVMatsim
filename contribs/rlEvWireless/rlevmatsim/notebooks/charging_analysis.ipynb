# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
initial_output = pd.read_csv(
    "/home/isaacp/repos/RLEVMatsim/contribs/rlEvWireless/results/ocp/ocp/happo/marl_ocp/seed-00001-2025-05-23-11-02-20/initial_output/output/ITERS/it.0/0.average_charge_time_profiles.txt",
    sep="\t",
)
best_output = pd.read_csv(
    "/home/isaacp/repos/RLEVMatsim/contribs/rlEvWireless/results/ocp/ocp/happo/marl_ocp/seed-00001-2025-05-23-11-02-20/best_output/output/ITERS/it.0/0.average_charge_time_profiles.txt",
    sep="\t",
)

# %%
initial_output.head()
# Out:
#     time  EV_65.0kWh  all vehicles
# 0  00:00         0.0           0.0
# 1  00:01         0.0           0.0
# 2  00:02         0.0           0.0
# 3  00:03         0.0           0.0
# 4  00:04         0.0           0.0

# %%
plt.plot(initial_output["time"], initial_output["EV_65.0kWh"], label="initial output")
plt.plot(best_output["time"], best_output["EV_65.0kWh"], label="best output")
plt.xticks([])
plt.legend()
plt.show()
